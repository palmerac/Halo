# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

# plt.style.use('dark_background')
import warnings
warnings.filterwarnings('ignore') 

start = time.perf_counter()

# %%
df = pd.read_csv('earl694412-infinite-matchhistory.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               643 non-null    object
#  1   Player             643 non-null    object
#  2   MatchId            643 non-null    object
#  3   Map                643 non-null    object
#  4   Category           643 non-null    object
#  5   Playlist           643 non-null    object
#  6   Input              643 non-null    object
#  7   Queue              643 non-null    object
#  8   PreCsr             643 non-null    int64
#  9   PostCsr            643 non-null    int64
#  10  Rank               643 non-null    int64
#  11  WasAtStart         643 non-null    int64
#  12  WasAtEnd           643 non-null    int64
#  13  WasInProgressJoin  643 non-null    int64
#  14  Mmr                2 non-null      float64
#  15  Outcome            643 non-null    object
#  16  Accuracy           643 non-null    float64
#  17  DamageDone         643 non-null    int64
#  18  DamageTaken        643 non-null    int64
#  19  ShotsFired         643 non-null    int64
#  20  ShotsLanded        643 non-null    int64
#  21  ShotsMissed        643 non-null    int64
#  22  KD                 643 non-null    float64
#  23  KDA                643 non-null    float64
#  24  TotalKills         643 non-null    int64
#  25  KillsMelee         643 non-null    int64
#  26  KillsGrenade       643 non-null    int64
#  27  KillsHeadshot      643 non-null    int64
#  28  KillsPower         643 non-null    int64
#  29  AssistsEmp         643 non-null    int64
#  30  AssistsDriver      643 non-null    int64
#  31  AssistsCallout     643 non-null    int64
#  32  Deaths             643 non-null    int64
#  33  Assists            643 non-null    int64
#  34  Betrayals          643 non-null    int64
#  35  Suicides           643 non-null    int64
#  36  MaxSpree           643 non-null    int64
#  37  VehicleDestroys    643 non-null    int64
#  38  VehicleHijacks     643 non-null    int64
#  39  ExpectedKills      642 non-null    float64
#  40  ExpectedDeaths     642 non-null    float64
#  41  Score              643 non-null    int64
#  42  Perfects           643 non-null    int64
#  43  Medals             643 non-null    int64
#  44  LengthSeconds      643 non-null    int64
# dtypes: float64(6), int64(30), object(9)
# memory usage: 226.2+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['LengthMinutes'] = df['LengthSeconds'] / 60
df['DamageRatio'] = df['DamageDone'] / df['DamageTaken']
df['Kills/10Min'] = (df['TotalKills'] / df['LengthMinutes']) * 10
df['Deaths/10Min'] = (df['Deaths'] / df['LengthMinutes']) * 10
df['Assists/10Min'] = (df['Assists'] / df['LengthMinutes']) * 10
df['Dmg/10Min'] = (df['DamageDone'] / df['LengthMinutes']) * 10
df['DmgT/10Min'] = (df['DamageTaken'] / df['LengthMinutes']) * 10
df['ExcessKills'] = df['TotalKills'] - df['ExpectedKills']
df['ExcessDeaths'] = df['ExpectedDeaths'] - df['Deaths']
df['ExcessKD'] = df['KD'] - round((df['ExpectedKills'] / df['ExpectedDeaths']),2)
df['LifetimeKD'] = df['TotalKills'].cumsum() / df['Deaths'].cumsum()
df['LifetimeDmgRatio'] = df['DamageDone'].cumsum() / df['DamageTaken'].cumsum()
df['LifetimeAcc'] = df['ShotsLanded'].cumsum() / df['ShotsFired'].cumsum() * 100
df['Map'] = df['Map'].str.replace(' - Ranked', '')

df = df.drop(['Player', 'MatchId', 'Input', 'Queue', 'Mmr'],axis=1)
dfr = df[df['Date']> '2023-01-01']
dfr = dfr[dfr['Playlist'] == 'Ranked Snipers']
dfr['Csr'] = dfr['Csr'].replace(0, method='ffill')
dfr = dfr[dfr['Outcome'] != 'Draw']
dfr = dfr[dfr['Outcome'] != 'Left']
dfr['Outcome'] = dfr['Outcome'].map({'Win': 1, 'Loss': 0})
dfr['LifetimeWinRate'] = (dfr['Outcome'].cumsum() / 
                          (dfr['Outcome'].cumsum() + 
                           dfr['Outcome'].eq(0).cumsum())).fillna(0)
dfr = dfr.drop('Playlist', axis=1).reset_index()
dfr.loc[:4, 'Csr'] = 808
dfr.to_csv('dfS.csv')
dfr.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 17
#      14 df['LifetimeAcc'] = df['ShotsLanded'].cumsum() / df['ShotsFired'].cumsum() * 100
#      15 df['Map'] = df['Map'].str.replace(' - Ranked', '')
# ---> 17 df = df.drop(['Player', 'MatchId', 'Input', 'Queue', 'Mmr'],axis=1)
#      18 dfr = df[df['Date']> '2023-01-01']
#      19 dfr = dfr[dfr['Playlist'] == 'Ranked Snipers']
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['Player', 'MatchId', 'Input', 'Queue', 'Mmr'] not found in axis"
